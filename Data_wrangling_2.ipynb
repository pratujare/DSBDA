# %%
import pandas as pd
import numpy as np
data=pd.read_csv("C:\\Users\\prati\\Documents\\Dsbda\\Data wrangling 2\\A2.csv")
data.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df=pd.DataFrame(data)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.isnull()
# Out:
#       Roll No   Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0       False  False      False      False      False      False       False
# 1       False  False      False      False      False       True       False
# 2       False  False      False      False      False      False       False
# 3       False  False      False      False       True      False       False
# 4       False  False      False      False      False      False       False
# ...       ...    ...        ...        ...        ...        ...         ...
# 996     False  False      False      False      False      False       False
# 997     False  False      False      False      False      False       False
# 998     False  False      False      False      False      False       False
# 999     False  False      False      False      False      False       False
# 1000    False  False      False      False      False      False       False
#
# [1001 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     1
# Subject 4     1
# Attendance    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(2)

# %%
pd.notnull(df)
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        True  True       True       True       True       True        True
# 1        True  True       True       True       True      False        True
# 2        True  True       True       True       True       True        True
# 3        True  True       True       True      False       True        True
# 4        True  True       True       True       True       True        True
# ...       ...   ...        ...        ...        ...        ...         ...
# 996      True  True       True       True       True       True        True
# 997      True  True       True       True       True       True        True
# 998      True  True       True       True       True       True        True
# 999      True  True       True       True       True       True        True
# 1000     True  True       True       True       True       True        True
#
# [1001 rows x 7 columns]

# %%
df=pd.DataFrame(data)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.ffill()
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       71.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.bfill()
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       99.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       84.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df.fillna({"Subject 3": df["Subject 3"].mean()},inplace=True)
df.fillna({"Subject 4": df["Subject 4"].mean()}, inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df.fillna({"Subject 3":df["Subject 3"].median()},inplace=True)
df.fillna({"Subject 4":df["Subject 4"].median()},inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df.fillna({"Subject 3":df["Subject 3"].mode()},inplace=True)
df.fillna({"Subject 4":df["Subject 4"].mode()},inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
nc=["Subject 1","Subject 2", "Subject 3", "Subject 4", "Attendance"]
for c in nc:
    df.fillna({c:df[c].mean()}, inplace = True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
nc=["Subject 1","Subject 2", "Subject 3", "Subject 4", "Attendance"]
for c in nc:
    df.fillna({c:df[c].median()}, inplace = True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
nc=["Subject 1","Subject 2", "Subject 3", "Subject 4", "Attendance"]
for c in nc:
    df.fillna({c:df[c].mode()}, inplace = True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df.fillna({"Subject 3": 80}, inplace=True)
df.fillna({"Subject 4": 90}, inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df.replace(to_replace=np.nan, value=80)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df=df.apply(pd.to_numeric, errors='coerce')
df.interpolate(method='linear',limit_direction='forward')
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0           1   NaN        100         62      73.00     92.000          96
# 1           2   NaN         72         97      82.00     80.545          78
# 2           3   NaN        100         88      71.00     99.000         -94
# 3           4   NaN         72         99      79.89     84.000          86
# 4           5   NaN         97         70      84.00     70.000          86
# ...       ...   ...        ...        ...        ...        ...         ...
# 996       997   NaN         88         68      84.00     66.000          98
# 997       998   NaN         61         96      62.00     84.000          83
# 998       999   NaN         72         76      90.00     72.000          90
# 999      1000   NaN         68         87     100.00     76.000          79
# 1000        1   NaN        100         62      73.00     92.000          96
#
# [1001 rows x 7 columns]

# %%
df=pd.DataFrame(data)
df.dropna()
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df.dropna(how='all', inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df.dropna(axis=1)
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df.dropna(axis=0)
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.DataFrame(data)
df.dropna(axis=0,how='any')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
data=pd.read_csv("C:\\Users\\prati\\Documents\\Dsbda\\Data wrangling 2\\A2.csv")
data.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df=pd.DataFrame(data)
df[df[["Subject 1", "Subject 2", "Subject 3","Subject 4","Attendance"]]<0]
# Out:
#       Roll No Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN  NaN        NaN        NaN        NaN        NaN       -94.0
# 3         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 4         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# ...       ...  ...        ...        ...        ...        ...         ...
# 996       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 997       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 998       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 999       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1000      NaN  NaN        NaN        NaN        NaN        NaN         NaN
#
# [1001 rows x 7 columns]

# %%
df[["Subject 1", "Subject 2", "Subject 3","Subject 4","Attendance"]]=df[["Subject 1", "Subject 2", "Subject 3","Subject 4","Attendance"]].clip(lower=0)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2              0
# 3             86
# ...

# %%
data=pd.read_csv("C:\\Users\\prati\\Documents\\Dsbda\\Data wrangling 2\\A2.csv")
data.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df=pd.DataFrame(data)
df.drop_duplicates(inplace=True)
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1        100         62       73.0       92.0
# 1          2     Student_2         72         97       82.0        NaN
# 2          3     Student_3        100         88       71.0       99.0
# 3          4     Student_4         72         99        NaN       84.0
# 4          5     Student_5         97         70       84.0       70.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996         74         89       85.0       71.0
# 996      997   Student_997         88         68       84.0       66.0
# 997      998   Student_998         61         96       62.0       84.0
# 998      999   Student_999         72         76       90.0       72.0
# 999     1000  Student_1000         68         87      100.0       76.0
#
#      Attendance
# 0            96
# 1            78
# 2           -94
# 3            86
# 4            86
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
nc=["Subject 1", "Subject 2", "Subject 3","Subject 4","Attendance"]
for c in nc:
    sns.boxplot(x=df[c])
    plt.title(f'box plot of {c}')
    plt.show()

# %%
for c in nc:
    Q1=df[c].quantile(0.25)
    Q3=df[c].quantile(0.75)
    IQR=Q3-Q1
    lowerbound=Q1-1.5*IQR
    upperbound=Q3+1.5*IQR
    df[c]=np.where((df[c]<lowerbound) | (df[c]>upperbound),df[c].median(),df[c])
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1      100.0       62.0       73.0       92.0
# 1          2     Student_2       72.0       97.0       82.0        NaN
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 3          4     Student_4       72.0       99.0        NaN       84.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance
# 0          96.0
# 1          78.0
# 2          86.0
# 3          86.0
# 4          86.0
# ...

# %%
data=pd.read_csv("C:\\Users\\prati\\Documents\\Dsbda\\Data wrangling 2\\A2.csv")
data.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df=pd.DataFrame(data)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
from scipy import stats
z=np.abs(stats.zscore(df["Subject 2"]))
z
# Out:
# array([1.51826974, 1.42330966, 0.66690353, ..., 0.34163798, 0.5828584 ,
#        1.51826974], shape=(1001,))

# %%
threshold=1
print(np.where(z>1))
# Out:
# (array([   0,    1,    3,    6,   10,   12,   13,   16,   17,   18,   22,
#          28,   34,   36,   38,   41,   42,   43,   44,   45,   46,   47,
#          48,   49,   51,   52,   53,   57,   65,   66,   67,   68,   70,
#          72,   73,   75,   76,   77,   79,   80,   82,   86,   87,   92,
#          97,  106,  107,  108,  109,  110,  111,  114,  119,  122,  125,
#         126,  127,  128,  130,  132,  133,  134,  135,  144,  145,  147,
#         148,  150,  154,  156,  157,  159,  165,  166,  167,  171,  172,
#         174,  177,  183,  184,  189,  190,  191,  193,  194,  195,  196,
#         198,  201,  203,  204,  207,  209,  211,  212,  214,  216,  217,
#         218,  221,  222,  226,  227,  229,  230,  231,  232,  233,  235,
#         238,  242,  244,  245,  246,  248,  250,  254,  256,  257,  258,
#         263,  265,  270,  272,  276,  280,  281,  282,  284,  287,  293,
#         294,  298,  299,  303,  309,  313,  314,  320,  322,  323,  326,
# ...

# %%
if(df['Attendance']<=0).any():
    df['Attendance']=df['Attendance'].clip(lower=1)
    print("\nReplace negative/zero values in 'Attendance' with 1 before log transfromation")

df['log Attendance']=np.log(df['Attendance'])
print("\nApplied log transformation to 'Attendance' column")
# Out:
# Applied log transformation to 'Attendance' column

# %%
data=pd.read_csv("C:\\Users\\prati\\Documents\\Dsbda\\Data wrangling 2\\A2.csv")
data.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("C:\\Users\\prati\\Documents\\Dsbda\\Data wrangling 2\\A2.csv")
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     1001 non-null   int64
#  1   Name        1001 non-null   object
#  2   Subject 1   1001 non-null   int64
#  3   Subject 2   1001 non-null   int64
#  4   Subject 3   1000 non-null   float64
#  5   Subject 4   1000 non-null   float64
#  6   Attendance  1001 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 54.9+ KB
# None

# %%
numerical_columns=df.select_dtypes(include=[np.number]).columns
skewness=df[numerical_columns].apply(lambda x: stats.skew(x,nan_policy='omit'))
print("\nSkewness of numerical columns: ")
print(skewness)
# Out:
# Skewness of numerical columns:
# Roll No            0.000021
# Subject 1          0.091273
# Subject 2         -0.010680
# Subject 3          0.006008
# Subject 4         -0.068195
# Attendance        -0.889829
# log Attendance   -16.872769
# dtype: float64

# %%
high_skew_columns=skewness[skewness.abs()>1].index
for column in high_skew_columns:
    plt.figure(figsize=(10,5))
    sns.histplot(df[column],kde=True,bins=30)
    plt.title(f'Distribution of {column} (Skewness: {skewness[column]:.2f})')
    plt.show()

# %%
print(df['Attendance'].isnull().sum())
print(np.isfinite(df['Attendance']).all())
print(df['Attendance'].head())
# Out:
# 0
# True
# 0    96
# 1    78
# 2     1
# 3    86
# 4    86
# Name: Attendance, dtype: int64

# %%
for column in high_skew_columns:
    if skewness[column] > 1:
        if (df[column] > 0).all():
            df[column] = np.log(df[column])
            print(f"\nApplied log transformation to {column}")
        else:
            print(f"\nSkipped log transformation for {column} due to non-positive values")

    elif skewness[column] < -1:
        if (df[column] >= 0).all():
            df[column] = np.sqrt(df[column])
            print(f"\nApplied square root transformation to {column}")
        else:
            print(f"\nSkipped square root transformation for {column} due to negative values")

if skewness['Attendance'] > 1 or skewness['Attendance'] < -1:
    if (df['Attendance'] > 0).all():
        df['Attendance'], _ = stats.boxcox(df['Attendance'])
        print("\nApplied Box-Cox transformation to 'Attendance' for skewness reduction")
    else:
        min_value = df['Attendance'].min()
        shift_value = abs(min_value) + 1
        df['Attendance'] = df['Attendance'] + shift_value
        print(f"\nShifted 'Attendance' by {shift_value} to make all values positive")
        
        df['Attendance'], _ = stats.boxcox(df['Attendance'])
        print("\nApplied Box-Cox transformation to 'Attendance' after shifting values")
# Out:
# Applied square root transformation to log Attendance

# %%
#1. Standard Scaling (Z-score normalization)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df['Attendance_scaled'] = scaler.fit_transform(df[['Attendance']])

# %%
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.boxplot(data=df[['Attendance', 'Attendance_scaled']])
plt.title('Boxplot of Attendance (Original vs Scaled)')
plt.tight_layout()
plt.show()

# %%
# 2. Min-Max Scaling
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['Attendance_minmax'] = scaler.fit_transform(df[['Attendance']])

# %%
#3. Log Transformation
df['log_Attendance'] = np.log(df['Attendance'] + 1)  # +1 handles zero values safely

# %%
 #4. Square Root Transformation
df['sqrt_Attendance'] = np.sqrt(df['Attendance'])

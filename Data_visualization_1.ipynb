# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv("C:\\Users\\prati\\Documents\\Dsbda\\Data visualization 1\\Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Example: Survival rate by gender
sns.countplot(df, x='Sex', hue='Survived')
plt.title("Survival Count by Gender")
plt.show()

# %%
# Example: Class distribution
sns.countplot(df, x='Pclass', hue='Survived')
plt.title("Survival Count by Class")
plt.show()

# %%
sns.distplot(df['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
#Replacement for above
#sns.histplot(data=df, x='Fare', kde=True)
#plt.title("Fare Distribution of Titanic Passengers")
#plt.xlabel("Fare")
#plt.ylabel("Count")
#plt.show()

# %%
sns.histplot(data=df, x='Fare', kde=True)
plt.title("Fare Distribution of Titanic Passengers")
plt.xlabel("Fare")
plt.ylabel("Count")
plt.show()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Sex')

# %%
sns.barplot(x='Sex',y='Age',hue='Sex',data=df,ci=None)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.countplot(x='Sex', hue='Sex', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.barplot(x='Pclass', y='Age',hue='Embarked', data=df, ci=None)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.countplot(x='Pclass', hue='Sex', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.catplot(x='Embarked',hue='Survived',kind='count', col='Pclass', data=df)

# %%
sns.scatterplot(x='Age', y='Fare', hue='Sex', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.histplot(data=df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot(df, x='Fare', binwidth=50)

# %%
sns.displot(df,x='Pclass')

# %%
sns.displot(df, x='SibSp')

# %%
sns.displot(df, x='Parch')

# %%
sns.displot(df, x='Survived')

# %%
sns.displot(data=df, x='Fare', col='Sex', binwidth=50, kde=False)

# %%
sns.displot(df,x='Fare', col='Pclass',binwidth=50)

# %%
sns.displot(df,x='Fare', col='Survived',binwidth=50)

# %%
ax=df.boxplot(column='Age',by='Sex', figsize=(10,5))
ax.set_ylabel('Age')
ax.set_title("Boxplot: Age vs Sex")
# Out:
# Text(0.5, 1.0, 'Boxplot: Age vs Sex')
